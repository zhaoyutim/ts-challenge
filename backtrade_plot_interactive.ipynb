# %%
import pandas as pd
import pickle
import argparse
import matplotlib.pyplot as plt
import os
from create_dataset import load_timeseries_data, split_train_test_data, drop_zero_columns, create_features
from catboost import CatBoostRegressor
import ipywidgets as widgets
from ipywidgets import interact
from backtrade import BackTradeTester, load_model, load_tick_data, plot_equity_curve, interactive_day_plot

def main():
    df = load_timeseries_data(stock_symbol=["002521"])
    _, test_df = split_train_test_data(df, split_date="2022-09-30")
    test_df = drop_zero_columns(test_df)
    test_df = create_features(test_df)
    
    print("After splitting by datetime:")
    print(f"Test set shape: {test_df.shape}")
    
    features = [col for col in test_df.columns if col not in 
                ['Return_1min', 'Return_5min', 'Return_10min', 'Return_1h', 
                 'Nano', 'DataTime', 'TradingDay', 'InstrumentID', 'TimeBinStart', 'TimeBinEnd']]
    print(test_df.columns)
    print("Length of features:", len(features))
    
    model = load_model('models/')
    
    # Initialize and run the backtest
    tester = BackTradeTester(model,
                             initial_capital=10000.0,
                             trade_size=1)
    equity_curve, trades = tester.run_backtest(test_df)
    price_series = test_df["LastPrice"].tolist()
    
    print("Final Equity: {:.2f}".format(equity_curve[-1]))
    print("Trade History:")
    for trade in trades:
        print(trade)
    
    interactive_day_plot(tester.timestamps, equity_curve, price_series, trades)
main()
# Out:
# Column 'ClosePrice' has only zeros
# Column 'HighestPrice' has only zeros
# Column 'LowerLimitPrice' has only zeros
# Column 'LowestPrice' has only zeros
# Column 'OpenPrice' has only zeros
# Column 'PreClosePrice' has only zeros
# Column 'PreSettlPrice' has only zeros
# Column 'SettlPrice' has only zeros
# Column 'TradesCount' has only zeros
# Column 'UpperLimitPrice' has only zeros
#
# Columns with only zeros: ['ClosePrice', 'HighestPrice', 'LowerLimitPrice', 'LowestPrice', 'OpenPrice', 'PreClosePrice', 'PreSettlPrice', 'SettlPrice', 'TradesCount', 'UpperLimitPrice']
# c:\Users\Yu\Time Series Data 194\feature_engineering.py:102: RuntimeWarning: divide by zero encountered in divide
#   returns = (shifted.values-df.values) / df.values
# c:\Users\Yu\Time Series Data 194\feature_engineering.py:102: RuntimeWarning: invalid value encountered in divide
#   returns = (shifted.values-df.values) / df.values
# c:\Users\Yu\Time Series Data 194\feature_engineering.py:102: RuntimeWarning: divide by zero encountered in divide
#   returns = (shifted.values-df.values) / df.values
# c:\Users\Yu\Time Series Data 194\feature_engineering.py:102: RuntimeWarning: invalid value encountered in divide
#   returns = (shifted.values-df.values) / df.values
# c:\Users\Yu\Time Series Data 194\feature_engineering.py:102: RuntimeWarning: divide by zero encountered in divide
#   returns = (shifted.values-df.values) / df.values
# c:\Users\Yu\Time Series Data 194\feature_engineering.py:102: RuntimeWarning: invalid value encountered in divide
#   returns = (shifted.values-df.values) / df.values
# c:\Users\Yu\Time Series Data 194\feature_engineering.py:102: RuntimeWarning: divide by zero encountered in divide
#   returns = (shifted.values-df.values) / df.values
# c:\Users\Yu\Time Series Data 194\feature_engineering.py:102: RuntimeWarning: invalid value encountered in divide
#   returns = (shifted.values-df.values) / df.values
# After splitting by datetime:
# Test set shape: (40026, 68)
# Index(['AskPrice1', 'AskPrice10', 'AskPrice2', 'AskPrice3', 'AskPrice4',
#        'AskPrice5', 'AskPrice6', 'AskPrice7', 'AskPrice8', 'AskPrice9',
#        'AskVolume1', 'AskVolume10', 'AskVolume2', 'AskVolume3', 'AskVolume4',
#        'AskVolume5', 'AskVolume6', 'AskVolume7', 'AskVolume8', 'AskVolume9',
#        'AveragePrice', 'BidPrice1', 'BidPrice10', 'BidPrice2', 'BidPrice3',
#        'BidPrice4', 'BidPrice5', 'BidPrice6', 'BidPrice7', 'BidPrice8',
#        'BidPrice9', 'BidVolume1', 'BidVolume10', 'BidVolume2', 'BidVolume3',
#        'BidVolume4', 'BidVolume5', 'BidVolume6', 'BidVolume7', 'BidVolume8',
#        'BidVolume9', 'DataTime', 'InstrumentID', 'LastPrice', 'Nano',
#        'TradingDay', 'Turnover', 'Volume', 'Return_1min', 'Return_5min',
#        'Return_10min', 'Return_1h', 'VolumeChange', 'LastPrice_return',
#        'Volatility_5min', 'RealizedVol_1min', 'RealizedVol_5min',
#        'RealizedVol_10min', 'Trades_1min', 'Trades_5min', 'TotalBookOrders',
#        'BookOrders_1min', 'ImbalancePrice_1min', 'ImbalancePrice_5min',
#        'ImbalancePrice_10min', 'WeightedImbalancePrice', 'TimeBinStart',
#        'TimeBinNumber'],
#       dtype='object')
# Length of features: 59
# Loaded CatBoost model from models/catboost_model_0.cbm
# Loaded CatBoost model from models/catboost_model_1.cbm
# Loaded CatBoost model from models/catboost_model_2.cbm
# Loaded CatBoost model from models/catboost_model_3.cbm
# Final Equity: 10038.04
# Trade History:
# {'timestamp': 1664501400127045260, 'action': 'OPEN', 'position': 100, 'price': 4.78}
# {'timestamp': 1664501427110162410, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.78, 'exit_price': 4.83, 'profit': 4.993247999999982}
# {'timestamp': 1664501427110162410, 'action': 'OPEN', 'position': -100, 'price': 4.83}
# {'timestamp': 1664501427203560104, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.83, 'exit_price': 4.82, 'profit': 0.9932499999999786}
# {'timestamp': 1664501427203560104, 'action': 'OPEN', 'position': 100, 'price': 4.82}
# {'timestamp': 1664501427256147365, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.82, 'exit_price': 4.82, 'profit': -0.0067480000000000005}
# {'timestamp': 1664501427256147365, 'action': 'OPEN', 'position': -100, 'price': 4.82}
# {'timestamp': 1664501429478267023, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.82, 'exit_price': 4.82, 'profit': -0.0067480000000000005}
# {'timestamp': 1664501429478267023, 'action': 'OPEN', 'position': 100, 'price': 4.82}
# {'timestamp': 1664501431482208424, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.82, 'exit_price': 4.82, 'profit': -0.0067480000000000005}
# {'timestamp': 1664501431482208424, 'action': 'OPEN', 'position': -100, 'price': 4.82}
# {'timestamp': 1664501431649709992, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.82, 'exit_price': 4.82, 'profit': -0.0067480000000000005}
# {'timestamp': 1664501431649709992, 'action': 'OPEN', 'position': 100, 'price': 4.82}
# {'timestamp': 1664501440296701237, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.82, 'exit_price': 4.82, 'profit': -0.0067480000000000005}
# {'timestamp': 1664501440296701237, 'action': 'OPEN', 'position': -100, 'price': 4.82}
# {'timestamp': 1664501440487749213, 'action': 'CLOSE', 'position': -100, 'entry_price': 4
 'action': 'CLOSE', 'position': -100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539593537506786, 'action': 'OPEN', 'position': 100, 'price': 4.83}
# {'timestamp': 1665539595117825583, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539595117825583, 'action': 'OPEN', 'position': -100, 'price': 4.83}
# {'timestamp': 1665539603761560824, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539603761560824, 'action': 'OPEN', 'position': 100, 'price': 4.83}
# {'timestamp': 1665539604962854894, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539604962854894, 'action': 'OPEN', 'position': -100, 'price': 4.83}
# {'timestamp': 1665539623979464271, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539623979464271, 'action': 'OPEN', 'position': 100, 'price': 4.83}
# {'timestamp': 1665539644455180896, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539644455180896, 'action': 'OPEN', 'position': -100, 'price': 4.83}
# {'timestamp': 1665539647869548581, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.83, 'exit_price': 4.82, 'profit': 0.9932499999999786}
# {'timestamp': 1665539647869548581, 'action': 'OPEN', 'position': 100, 'price': 4.82}
# {'timestamp': 1665539655906539822, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.82, 'exit_price': 4.83, 'profit': 0.9932399999999787}
# {'timestamp': 1665539655906539822, 'action': 'OPEN', 'position': -100, 'price': 4.83}
# {'timestamp': 1665539676188387311, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539676188387311, 'action': 'OPEN', 'position': 100, 'price': 4.83}
# {'timestamp': 1665539676202945342, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539676202945342, 'action': 'OPEN', 'position': -100, 'price': 4.83}
# {'timestamp': 1665539677093402918, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539677093402918, 'action': 'OPEN', 'position': 100, 'price': 4.83}
# {'timestamp': 1665539677529001754, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539677529001754, 'action': 'OPEN', 'position': -100, 'price': 4.83}
# {'timestamp': 1665539677575454668, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539677575454668, 'action': 'OPEN', 'position': 100, 'price': 4.83}
# {'timestamp': 1665539678268089239, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539678268089239, 'action': 'OPEN', 'position': -100, 'price': 4.83}
# {'timestamp': 1665539678523689414, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539678523689414, 'action': 'OPEN', 'position': 100, 'price': 4.83}
# {'timestamp': 1665539706529724111, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.83, 'exit_price': 4.82, 'profit': -1.0067499999999787}
# {'timestamp': 1665539706529724111, 'action': 'OPEN', 'position': -100, 'price': 4.82}
# {'timestamp': 1665539754961494450, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.82, 'exit_price': 4.83, 'profit': -1.0067599999999786}
# {'timestamp': 1665539754961494450, 'action': 'OPEN', 'position': 100, 'price': 4.83}
# {'timestamp': 1665539788498897723, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539788498897723, 'action': 'OPEN', 'position': -100, 'price': 4.83}
# {'timestamp': 1665539803477299539, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.83, 'exit_price': 4.82, 'profit': 0.9932499999999786}
# {'timestamp': 1665539803477299539, 'action': 'OPEN', 'position': 100, 'price': 4.82}
# {'timestamp': 1665539825246488026, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.82, 'exit_price': 4.83, 'profit': 0.9932399999999787}
# {'timestamp': 1665539825246488026, 'action': 'OPEN', 'position': -100, 'price': 4.83}
# {'timestamp': 1665539835767031635, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539835767031635, 'action': 'OPEN', 'position': 100, 'price': 4.83}
# {'timestamp': 1665539851504163346, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539851504163346, 'action': 'OPEN', 'position': -100, 'price': 4.83}
# {'timestamp': 1665539894222701575, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.83, 'exit_price': 4.82, 'profit': 0.9932499999999786}
# {'timestamp': 1665539894222701575, 'action': 'OPEN', 'position': 100, 'price': 4.82}
# {'timestamp': 1665539939785834127, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.82, 'exit_price': 4.83, 'profit': 0.9932399999999787}
# {'timestamp': 1665539939785834127, 'action': 'OPEN', 'position': -100, 'price': 4.83}
# {'timestamp': 1665539939928180759, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539939928180759, 'action': 'OPEN', 'position': 100, 'price': 4.83}
# {'timestamp': 1665539939929190867, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539939929190867, 'action': 'OPEN', 'position': -100, 'price': 4.83}
# {'timestamp': 1665539939978555291, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539939978555291, 'action': 'OPEN', 'position': 100, 'price': 4.83}
# {'timestamp': 1665539939981705368, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539939981705368, 'action': 'OPEN', 'position': -100, 'price': 4.83}
# {'timestamp': 1665539939988785738, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539939988785738, 'action': 'OPEN', 'position': 100, 'price': 4.83}
# {'timestamp': 1665539939989515367, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539939989515367, 'action': 'OPEN', 'position': -100, 'price': 4.83}
# {'timestamp': 1665539940021019417, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539940021019417, 'action': 'OPEN', 'position': 100, 'price': 4.83}
# {'timestamp': 1665539940031827032, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539940031827032, 'action': 'OPEN', 'position': -100, 'price': 4.83}
# {'timestamp': 1665539940083235977, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539940083235977, 'action': 'OPEN', 'position': 100, 'price': 4.83}
# {'timestamp': 1665539940647994092, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665539940647994092, 'action': 'OPEN', 'position': -100, 'price': 4.83}
# {'timestamp': 1665540004847393085, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.006762}
# {'timestamp': 1665624601282757658, 'action': 'OPEN', 'position': -100, 'price': 4.93}
# {'timestamp': 1665625171831979710, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.93, 'exit_price': 4.9, 'profit': 2.993133999999936}
# {'timestamp': 1665625171831979710, 'action': 'OPEN', 'position': 100, 'price': 4.9}
# {'timestamp': 1665625181408148190, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.9, 'exit_price': 4.88, 'profit': -2.0068360000000465}
# {'timestamp': 1665625181408148190, 'action': 'OPEN', 'position': -100, 'price': 4.88}
# {'timestamp': 1665625207535132172, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': -0.0068319999999999995}
# {'timestamp': 1665625207535132172, 'action': 'OPEN', 'position': 100, 'price': 4.88}
# {'timestamp': 1665625223741194749, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.88, 'exit_price': 4.89, 'profit': 0.9931559999999787}
# {'timestamp': 1665625223741194749, 'action': 'OPEN', 'position': -100, 'price': 4.89}
# {'timestamp': 1665626401814836090, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.89, 'exit_price': 4.9, 'profit': -1.0068580000000675}
# interactive(children=(Dropdown(description='Day:', options=(datetime.date(2022, 9, 30), datetime.date(2022, 10…
