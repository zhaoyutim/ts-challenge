# %%
import pandas as pd
import pickle
import argparse
import matplotlib.pyplot as plt
import os
from create_dataset import load_timeseries_data, split_train_test_data, drop_zero_columns, create_features
from catboost import CatBoostRegressor
import ipywidgets as widgets
from ipywidgets import interact
from backtrade import BackTradeTester, load_model, load_tick_data, plot_equity_curve, interactive_day_plot

def main():
    df = load_timeseries_data(stock_symbol=["002521"])
    _, test_df = split_train_test_data(df, split_date="2022-09-30")
    test_df = drop_zero_columns(test_df)
    test_df = create_features(test_df)
    
    print("After splitting by datetime:")
    print(f"Test set shape: {test_df.shape}")
    
    features = [col for col in df.columns if col not in 
                ['Return_1min', 'Return_5min', 'Return_10min', 'Return_1h', 
                 'Nano', 'DataTime', 'TradingDay', 'InstrumentID', 'TimeBinStart', 'TimeBinEnd']]
    print(df.columns)
    print("Length of features:", len(features))
    
    model = load_model('models/')
    
    # Initialize and run the backtest
    tester = BackTradeTester(model,
                             initial_capital=10000.0,
                             trade_size=1,
                             transaction_cost=0)
    equity_curve, trades = tester.run_backtest(test_df)
    price_series = test_df["LastPrice"].tolist()
    
    print("Final Equity: {:.2f}".format(equity_curve[-1]))
    print("Trade History:")
    for trade in trades:
        print(trade)
    
    interactive_day_plot(tester.timestamps, equity_curve, price_series, trades)
main()
# Out:
# Column 'ClosePrice' has only zeros
# Column 'HighestPrice' has only zeros
# Column 'LowerLimitPrice' has only zeros
# Column 'LowestPrice' has only zeros
# Column 'OpenPrice' has only zeros
# Column 'PreClosePrice' has only zeros
# Column 'PreSettlPrice' has only zeros
# Column 'SettlPrice' has only zeros
# Column 'TradesCount' has only zeros
# Column 'UpperLimitPrice' has only zeros
#
# Columns with only zeros: ['ClosePrice', 'HighestPrice', 'LowerLimitPrice', 'LowestPrice', 'OpenPrice', 'PreClosePrice', 'PreSettlPrice', 'SettlPrice', 'TradesCount', 'UpperLimitPrice']
# After splitting by datetime:
# Test set shape: (40026, 59)
# Index(['AskPrice1', 'AskPrice10', 'AskPrice2', 'AskPrice3', 'AskPrice4',
#        'AskPrice5', 'AskPrice6', 'AskPrice7', 'AskPrice8', 'AskPrice9',
#        'AskVolume1', 'AskVolume10', 'AskVolume2', 'AskVolume3', 'AskVolume4',
#        'AskVolume5', 'AskVolume6', 'AskVolume7', 'AskVolume8', 'AskVolume9',
#        'AveragePrice', 'BidPrice1', 'BidPrice10', 'BidPrice2', 'BidPrice3',
#        'BidPrice4', 'BidPrice5', 'BidPrice6', 'BidPrice7', 'BidPrice8',
#        'BidPrice9', 'BidVolume1', 'BidVolume10', 'BidVolume2', 'BidVolume3',
#        'BidVolume4', 'BidVolume5', 'BidVolume6', 'BidVolume7', 'BidVolume8',
#        'BidVolume9', 'ClosePrice', 'DataTime', 'HighestPrice', 'InstrumentID',
#        'LastPrice', 'LowerLimitPrice', 'LowestPrice', 'Nano', 'OpenPrice',
#        'PreClosePrice', 'PreSettlPrice', 'SettlPrice', 'TradesCount',
#        'TradingDay', 'Turnover', 'UpperLimitPrice', 'Volume'],
#       dtype='object')
# Length of features: 54
# c:\Users\Yu\Time Series Data 194\feature_engineering.py:70: RuntimeWarning: divide by zero encountered in divide
#   returns = (shifted.values-df.values) / df.values
# c:\Users\Yu\Time Series Data 194\feature_engineering.py:70: RuntimeWarning: invalid value encountered in divide
#   returns = (shifted.values-df.values) / df.values
# c:\Users\Yu\Time Series Data 194\feature_engineering.py:70: RuntimeWarning: divide by zero encountered in divide
#   returns = (shifted.values-df.values) / df.values
# c:\Users\Yu\Time Series Data 194\feature_engineering.py:70: RuntimeWarning: invalid value encountered in divide
#   returns = (shifted.values-df.values) / df.values
# c:\Users\Yu\Time Series Data 194\feature_engineering.py:70: RuntimeWarning: divide by zero encountered in divide
#   returns = (shifted.values-df.values) / df.values
# c:\Users\Yu\Time Series Data 194\feature_engineering.py:70: RuntimeWarning: invalid value encountered in divide
#   returns = (shifted.values-df.values) / df.values
# c:\Users\Yu\Time Series Data 194\feature_engineering.py:70: RuntimeWarning: divide by zero encountered in divide
#   returns = (shifted.values-df.values) / df.values
# c:\Users\Yu\Time Series Data 194\feature_engineering.py:70: RuntimeWarning: invalid value encountered in divide
#   returns = (shifted.values-df.values) / df.values
# Loaded CatBoost model from models/catboost_model_0.cbm
# Loaded CatBoost model from models/catboost_model_1.cbm
# Loaded CatBoost model from models/catboost_model_2.cbm
# Loaded CatBoost model from models/catboost_model_3.cbm
# Final Equity: 10051.00
# Trade History:
# {'timestamp': 1664501400127045260, 'action': 'OPEN', 'position': 100, 'price': 4.78}
# {'timestamp': 1664502847517478007, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.78, 'exit_price': 4.84, 'profit': 5.999999999999961}
# {'timestamp': 1664502847517478007, 'action': 'OPEN', 'position': -100, 'price': 4.84}
# {'timestamp': 1664502854347770820, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.84, 'exit_price': 4.84, 'profit': -0.0}
# {'timestamp': 1664502854347770820, 'action': 'OPEN', 'position': 100, 'price': 4.84}
# {'timestamp': 1664502880492070956, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.84, 'exit_price': 4.84, 'profit': 0.0}
# {'timestamp': 1664502880492070956, 'action': 'OPEN', 'position': -100, 'price': 4.84}
# {'timestamp': 1664502907534710851, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.84, 'exit_price': 4.83, 'profit': 0.9999999999999787}
# {'timestamp': 1664502907534710851, 'action': 'OPEN', 'position': 100, 'price': 4.83}
# {'timestamp': 1664502914182122001, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': 0.0}
# {'timestamp': 1664502914182122001, 'action': 'OPEN', 'position': -100, 'price': 4.83}
# {'timestamp': 1664502916537241518, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.83, 'exit_price': 4.84, 'profit': -0.9999999999999787}
# {'timestamp': 1664502916537241518, 'action': 'OPEN', 'position': 100, 'price': 4.84}
# {'timestamp': 1664502916633688617, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.84, 'exit_price': 4.84, 'profit': 0.0}
# {'timestamp': 1664502916633688617, 'action': 'OPEN', 'position': -100, 'price': 4.84}
# {'timestamp': 1664502946711332971, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.84, 'exit_price': 4.84, 'profit': -0.0}
# {'timestamp': 1664502946711332971, 'action': 'OPEN', 'position': 100, 'price': 4.84}
# {'timestamp': 1664502963647582080, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.84, 'exit_price': 4.84, 'profit': 0.0}
# {'timestamp': 1664502963647582080, 'action': 'OPEN', 'position': -100, 'price': 4.84}
# {'timestamp': 1664502964521717895, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.84, 'exit_price': 4.84, 'profit': -0.0}
# {'timestamp': 1664502964521717895, 'action': 'OPEN', 'position': 100, 'price': 4.84}
# {'timestamp': 1664503085229443314, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.84, 'exit_price': 4.84, 'profit': 0.0}
# {'timestamp': 1664503085229443314, 'action': 'OPEN', 'position': -100, 'price': 4.84}
# {'timestamp': 1664503089679485221, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.84, 'exit_price': 4.84, 'profit': -0.0}
# {'timestamp': 1664503089679485221, 'action': 'OPEN', 'position': 100, 'price': 4.84}
# {'timestamp': 1664503166933415345, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.84, 'exit_price': 4.84, 'profit': 0.0}
# {'timestamp': 1664503166933415345, 'action': 'OPEN', 'position': -100, 'price': 4.84}
# {'timestamp': 1664503171846246874, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.84, 'exit_price': 4.84, 'profit': -0.0}
# {'timestamp': 1664503171846246874, 'action': 'OPEN', 'position': 100, 'price': 4.84}
# {'timestamp': 1665365896869728268, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.84, 'exit_price': 4.88, 'profit': 4.0000000000000036}
# {'timestamp': 1665365896869728268, 'action': 'OPEN', 'position': -100, 'price': 4.88}
# {'timestamp': 1665365896874631630, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': -0.0}
# {'timestamp': 1665365896874631630, 'action': 'OPEN', 'position': 100, 'price': 4.88}
# {'timestamp': 1665365896884455123, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': 0.0}
# {'timestamp': 1665365896884455123, 'action': 'OPEN', 'position': -100, 'price': 4.88}
# {'timestamp': 1665365897019488218, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': -0.0}
# {'timestamp': 1665365897019488218, 'action': 'OPEN', 'position': 100, 'price': 4.88}
# {'timestamp': 1665365897048856514, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.88, 'exit_price': 4.87, 'profit': -0.9999999999999787}
# {'timestamp': 1665365897048856514, 'action': 'OPEN', 'position': -100, 'price': 4.87}
# {'timestamp': 1665365900091595046, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.87, 'exit_price': 4.87, 'profit': -0.0}
# {'timestamp': 1665365900091595046, 'action': 'OPEN', 'position': 100, 'price': 4.87}
# {'timestamp': 1665365900100594761, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.87, 'exit_price': 4.88, 'profit': 0.9999999999999787}
# {'timestamp': 1665365900100594761, 'action': 'OPEN', 'position': -100, 'price': 4.88}
# {'timestamp': 1665365906189687813, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': -0.0}
# {'timestamp': 1665365906189687813, 'action': 'OPEN', 'position': 100, 'price': 4.88}
# {'timestamp': 1665365906203644115, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': 0.0}
# {'timestamp': 1665365906203644115, 'action': 'OPEN', 'position': -100, 'price': 4.88}
# {'timestamp': 1665365906236837536, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': -0.0}
# {'timestamp': 1665365906236837536, 'action': 'OPEN', 'position': 100, 'price': 4.88}
# {'timestamp': 1665365908501223843, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': 0.0}
# {'timestamp': 1665365908501223843, 'action': 'OPEN', 'position': -100, 'price': 4.88}
# {'timestamp': 1665365956837901883, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.88, 'exit_price': 4.87, 'profit': 0.9999999999999787}
# {'timestamp': 1665365956837901883, 'action': 'OPEN', 'position': 100, 'price': 4.87}
# {'timestamp': 1665365981218036728, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.87, 'exit_price': 4.88, 'profit': 0.9999999999999787}
# {'timestamp': 1665365981218036728, 'action': 'OPEN', 'position': -100, 'price': 4.88}
# {'timestamp': 1665365981218171584, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.88, 'exit_price': 4.87, 'profit': 0.9999999999999787}
# {'timestamp': 1665365981218171584, 'action': 'OPEN', 'position': 100, 'price': 4.87}
# {'timestamp': 1665366002637688156, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.87, 'exit_price': 4.87, 'profit': 0.0}
# {'timestamp': 1665366002637688156, 'action': 'OPEN', 'position': -100, 'price': 4.87}
# {'timestamp': 1665366003273808135, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.87, 'exit_price': 4.88, 'profit': -0.9999999999999787}
# {'timestamp': 1665366003273808135, 'action': 'OPEN', 'position': 100, 'price': 4.88}
# {'timestamp': 1665366004502696642, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': 0.0}
# {'timestamp': 1665366004502696642, 'action': 'OPEN', 'position': -100, 'price': 4.88}
# {'timestamp': 1665366004523030908, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': -0.0}
# {'timestamp': 1665366004523030908, 'action': 'OPEN', 'position': 100, 'price': 4.88}
# {'timestamp': 1665366004537242974, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': 0.0}
# {'timestamp': 1665366004537242974, 'action': 'OPEN', 'position': -100, 'price': 4.88}
# {'timestamp': 1665366004556660961, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': -0.0}
# {'timestamp': 1665366004556660961, 'action': 'OPEN', 'position': 100, 'price': 4.88}
# {'timestamp': 1665366004625300236, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': 0.0}
# {'timestamp': 1665366004625300236, 'action': 'OPEN', 'position': -100, 'price': 4.88}
# {'timestamp': 1665366004797048619, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': -0.0}
# {'timestamp': 1665366004797048619, 'action': 'OPEN', 'position': 100, 'price': 4.88}
# {'timestamp': 1665366005247661564, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': 0.0}
# {'timestamp': 1665366005247661564, 'action': 'OPEN', 'position': -100, 'price': 4.88}
# {'timestamp': 1665366005277189265, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': -0.0}
# {'timestamp': 1665366005277189265, 'action': 'OPEN', 'position': 100, 'price': 4.88}
# {'timestamp': 1665366005277196347, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': 0.0}
# {'timestamp': 1665366005277196347, 'action': 'OPEN', 'position': -100, 'price': 4.88}
# {'timestamp': 1665366006195804897, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.88, 'exit_price': 4.89, 'profit': -0.9999999999999787}
# {'timestamp': 1665366006195804897, 'action': 'OPEN', 'position': 100, 'price': 4.89}
# {'timestamp': 1665366051646291929, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.89, 'exit_price': 4.89, 'profit': 0.0}
# {'timestamp': 1665366051646291929, 'action': 'OPEN', 'position': -100, 'price': 4.89}
# {'timestamp': 1665366051655177310, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.89, 'exit_price': 4.89, 'profit': -0.0}
# {'timestamp': 1665366051655177310, 'action': 'OPEN', 'position': 100, 'price': 4.89}
# {'timestamp': 1665366064569608093, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.89, 'exit_price': 4.89, 'profit': 0.0}
# {'timestamp': 1665366064569608093, 'action': 'OPEN', 'position': -100, 'price': 4.89}
# {'timestamp': 1665366064810263461, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.89, 'exit_price': 4.89, 'profit': -0.0}
# {'timestamp': 1665366064810263461, 'action': 'OPEN', 'position': 100, 'price': 4.89}
# {'timestamp': 1665366064816859366, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.89, 'exit_price': 4.89, 'profit': 0.0}
# {'timestamp': 1665366064816859366, 'action': 'OPEN', 'position': -100, 'price': 4.89}
# {'timestamp': 1665366069147160107, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.89, 'exit_price': 4.89, 'profit': -0.0}
# {'timestamp': 1665366069147160107, 'action': 'OPEN', 'position': 100, 'price': 4.89}
# {'timestamp': 1665366078931176490, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.89, 'exit_price': 4.89, 'profit': 0.0}
# {'timestamp': 1665366078931176490, 'action': 'OPEN', 'position': -100, 'price': 4.89}
# {'timestamp': 1665366081213829739, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.89, 'exit_price': 4.89, 'profit': -0.0}
# {'timestamp': 1665366081213829739, 'action': 'OPEN', 'position': 100, 'price': 4.89}
# {'timestamp': 1665366108437818939, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.89, 'exit_price': 4.89, 'profit': 0.0}
# {'timestamp': 1665366108437818939, 'action': 'OPEN', 'position': -100, 'price': 4.89}
# {'timestamp': 1665366109420089713, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.89, 'exit_price': 4.89, 'profit': -0.0}
# {'timestamp': 1665366109420089713, 'action': 'OPEN', 'position': 100, 'price': 4.89}
# {'timestamp': 1665366134080013382, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.89, 'exit_price': 4.88, 'profit': -0.9999999999999787}
# {'timestamp': 1665366134080013382, 'action': 'OPEN', 'position': -100, 'price': 4.88}
# {'timestamp': 1665366156341215039, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': -0.0}
# {'timestamp': 1665366156341215039, 'action': 'OPEN', 'position': 100, 'price': 4.88}
# {'timestamp': 1665366163507735274, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': 0.0}
# {'timestamp': 1665366163507735274, 'action': 'OPEN', 'position': -100, 'price': 4.88}
# {'timestamp': 1665366163516482624, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': -0.0}
# {'timestamp': 1665366163516482624, 'action': 'OPEN', 'position': 100, 'price': 4.88}
# {'timestamp': 1665366164368020765, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': 0.0}
# {'timestamp': 1665366164368020765, 'action': 'OPEN', 'position': -100, 'price': 4.88}
# {'timestamp': 1665366166486608449, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': -0.0}
# {'timestamp': 1665366166486608449, 'action': 'OPEN', 'position': 100, 'price': 4.88}
# {'timestamp': 1665366166497700721, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': 0.0}
# {'timestamp': 1665366166497700721, 'action': 'OPEN', 'position': -100, 'price': 4.88}
# {'timestamp': 1665366175093226918, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': -0.0}
# {'timestamp': 1665366175093226918, 'action': 'OPEN', 'position': 100, 'price': 4.88}
# {'timestamp': 1665366178180632416, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': 0.0}
# {'timestamp': 1665366178180632416, 'action': 'OPEN', 'position': -100, 'price': 4.88}
# {'timestamp': 1665366178195867228, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': -0.0}
# {'timestamp': 1665366178195867228, 'action': 'OPEN', 'position': 100, 'price': 4.88}
# {'timestamp': 1665366178383084996, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': 0.0}
# {'timestamp': 1665366178383084996, 'action': 'OPEN', 'position': -100, 'price': 4.88}
# {'timestamp': 1665366607503103031, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.88, 'exit_price': 4.89, 'profit': -0.9999999999999787}
# {'timestamp': 1665366607503103031, 'action': 'OPEN', 'position': 100, 'price': 4.89}
# {'timestamp': 1665366607734817842, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.89, 'exit_price': 4.89, 'profit': 0.0}
# {'timestamp': 1665366607734817842, 'action': 'OPEN', 'position': -100, 'price': 4.89}
# {'timestamp': 1665366607876164402, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.89, 'exit_price': 4.89, 'profit': -0.0}
# {'timestamp': 1665366607876164402, 'action': 'OPEN', 'position': 100, 'price': 4.89}
# {'timestamp': 1665366613517755005, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.89, 'exit_price': 4.89, 'profit': 0.0}
# {'timestamp': 1665366613517755005, 'action': 'OPEN', 'position': -100, 'price': 4.89}
# {'timestamp': 1665366620264920008, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.89, 'exit_price': 4.89, 'profit': -0.0}
# {'timestamp': 1665366620264920008, 'action': 'OPEN', 'position': 100, 'price': 4.89}
# {'timestamp': 1665366625497303721, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.89, 'exit_price': 4.89, 'profit': 0.0}
# {'timestamp': 1665366625497303721, 'action': 'OPEN', 'position': -100, 'price': 4.89}
# {'timestamp': 1665366643986318038, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.89, 'exit_price': 4.89, 'profit': -0.0}
# {'timestamp': 1665366643986318038, 'action': 'OPEN', 'position': 100, 'price': 4.89}
# {'timestamp': 1665366784102093665, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.89, 'exit_price': 4.91, 'profit': 2.000000000000046}
# {'timestamp': 1665366784102093665, 'action': 'OPEN', 'position': -100, 'price': 4.91}
# {'timestamp': 1665366786092364477, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.91, 'exit_price': 4.9, 'profit': 0.9999999999999787}
# {'timestamp': 1665366786092364477, 'action': 'OPEN', 'position': 100, 'price': 4.9}
# {'timestamp': 1665539130900127458, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.9, 'exit_price': 4.82, 'profit': -8.000000000000007}
# {'timestamp': 1665539130900127458, 'action': 'OPEN', 'position': -100, 'price': 4.82}
# {'timestamp': 1665539132890828209, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.82, 'exit_price': 4.82, 'profit': -0.0}
# {'timestamp': 1665539132890828209, 'action': 'OPEN', 'position': 100, 'price': 4.82}
# {'timestamp': 1665539644455180896, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.82, 'exit_price': 4.83, 'profit': 0.9999999999999787}
# {'timestamp': 1665539644455180896, 'action': 'OPEN', 'position': -100, 'price': 4.83}
# {'timestamp': 1665539647869548581, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.83, 'exit_price': 4.82, 'profit': 0.9999999999999787}
# {'timestamp': 1665539647869548581, 'action': 'OPEN', 'position': 100, 'price': 4.82}
# {'timestamp': 1665539678523689414, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.82, 'exit_price': 4.83, 'profit': 0.9999999999999787}
# {'timestamp': 1665539678523689414, 'action': 'OPEN', 'position': -100, 'price': 4.83}
# {'timestamp': 1665539679406873487, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.83, 'exit_price': 4.82, 'profit': 0.9999999999999787}
# {'timestamp': 1665539679406873487, 'action': 'OPEN', 'position': 100, 'price': 4.82}
# {'timestamp': 1665539710741053536, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.82, 'exit_price': 4.84, 'profit': 1.9999999999999574}
# {'timestamp': 1665539710741053536, 'action': 'OPEN', 'position': -100, 'price': 4.84}
# {'timestamp': 1665539722381301183, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.84, 'exit_price': 4.83, 'profit': 0.9999999999999787}
# {'timestamp': 1665539722381301183, 'action': 'OPEN', 'position': 100, 'price': 4.83}
# {'timestamp': 1665539723748873697, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': 0.0}
# {'timestamp': 1665539723748873697, 'action': 'OPEN', 'position': -100, 'price': 4.83}
# {'timestamp': 1665539825229793389, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.83, 'exit_price': 4.82, 'profit': 0.9999999999999787}
# {'timestamp': 1665539825229793389, 'action': 'OPEN', 'position': 100, 'price': 4.82}
# {'timestamp': 1665539825246488026, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.82, 'exit_price': 4.83, 'profit': 0.9999999999999787}
# {'timestamp': 1665539825246488026, 'action': 'OPEN', 'position': -100, 'price': 4.83}
# {'timestamp': 1665539905535919414, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.83, 'exit_price': 4.82, 'profit': 0.9999999999999787}
# {'timestamp': 1665539905535919414, 'action': 'OPEN', 'position': 100, 'price': 4.82}
# {'timestamp': 1665539939672429401, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.82, 'exit_price': 4.83, 'profit': 0.9999999999999787}
# {'timestamp': 1665539939672429401, 'action': 'OPEN', 'position': -100, 'price': 4.83}
# {'timestamp': 1665539940647994092, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.83, 'exit_price': 4.83, 'profit': -0.0}
# {'timestamp': 1665539940647994092, 'action': 'OPEN', 'position': 100, 'price': 4.83}
# {'timestamp': 1665539944540998333, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.83, 'exit_price': 4.84, 'profit': 0.9999999999999787}
# {'timestamp': 1665539944540998333, 'action': 'OPEN', 'position': -100, 'price': 4.84}
# {'timestamp': 1665539947503517232, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.84, 'exit_price': 4.84, 'profit': -0.0}
# {'timestamp': 1665539947503517232, 'action': 'OPEN', 'position': 100, 'price': 4.84}
# {'timestamp': 1665539993841739641, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.84, 'exit_price': 4.84, 'profit': 0.0}
# {'timestamp': 1665539993841739641, 'action': 'OPEN', 'position': -100, 'price': 4.84}
# {'timestamp': 1665539993846379660, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.84, 'exit_price': 4.84, 'profit': -0.0}
# {'timestamp': 1665539993846379660, 'action': 'OPEN', 'position': 100, 'price': 4.84}
# {'timestamp': 1665539994109406997, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.84, 'exit_price': 4.84, 'profit': 0.0}
# {'timestamp': 1665539994109406997, 'action': 'OPEN', 'position': -100, 'price': 4.84}
# {'timestamp': 1665539994112456300, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.84, 'exit_price': 4.84, 'profit': -0.0}
# {'timestamp': 1665539994112456300, 'action': 'OPEN', 'position': 100, 'price': 4.84}
# {'timestamp': 1665624602133513830, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.84, 'exit_price': 4.93, 'profit': 8.999999999999986}
# {'timestamp': 1665624602133513830, 'action': 'OPEN', 'position': -100, 'price': 4.93}
# {'timestamp': 1665624602212896464, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.93, 'exit_price': 4.93, 'profit': -0.0}
# {'timestamp': 1665624602212896464, 'action': 'OPEN', 'position': 100, 'price': 4.93}
# {'timestamp': 1665624602283032463, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.93, 'exit_price': 4.93, 'profit': 0.0}
# {'timestamp': 1665624602283032463, 'action': 'OPEN', 'position': -100, 'price': 4.93}
# {'timestamp': 1665624604251752250, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.93, 'exit_price': 4.9, 'profit': 2.999999999999936}
# {'timestamp': 1665624604251752250, 'action': 'OPEN', 'position': 100, 'price': 4.9}
# {'timestamp': 1665624609536358701, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.9, 'exit_price': 4.91, 'profit': 0.9999999999999787}
# {'timestamp': 1665624609536358701, 'action': 'OPEN', 'position': -100, 'price': 4.91}
# {'timestamp': 1665624609536406065, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.91, 'exit_price': 4.9, 'profit': 0.9999999999999787}
# {'timestamp': 1665624609536406065, 'action': 'OPEN', 'position': 100, 'price': 4.9}
# {'timestamp': 1665624611413936287, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.9, 'exit_price': 4.93, 'profit': 2.999999999999936}
# {'timestamp': 1665624611413936287, 'action': 'OPEN', 'position': -100, 'price': 4.93}
# {'timestamp': 1665624611413939962, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.93, 'exit_price': 4.9, 'profit': 2.999999999999936}
# {'timestamp': 1665624611413939962, 'action': 'OPEN', 'position': 100, 'price': 4.9}
# {'timestamp': 1665624611508221674, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.9, 'exit_price': 4.93, 'profit': 2.999999999999936}
# {'timestamp': 1665624611508221674, 'action': 'OPEN', 'position': -100, 'price': 4.93}
# {'timestamp': 1665624611894550390, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.93, 'exit_price': 4.93, 'profit': -0.0}
# {'timestamp': 1665624611894550390, 'action': 'OPEN', 'position': 100, 'price': 4.93}
# {'timestamp': 1665624632415022776, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.93, 'exit_price': 4.91, 'profit': -1.9999999999999574}
# {'timestamp': 1665624632415022776, 'action': 'OPEN', 'position': -100, 'price': 4.91}
# {'timestamp': 1665624632437989096, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.91, 'exit_price': 4.91, 'profit': -0.0}
# {'timestamp': 1665624632437989096, 'action': 'OPEN', 'position': 100, 'price': 4.91}
# {'timestamp': 1665624634525683311, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.91, 'exit_price': 4.91, 'profit': 0.0}
# {'timestamp': 1665624634525683311, 'action': 'OPEN', 'position': -100, 'price': 4.91}
# {'timestamp': 1665624634525683761, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.91, 'exit_price': 4.91, 'profit': -0.0}
# {'timestamp': 1665624634525683761, 'action': 'OPEN', 'position': 100, 'price': 4.91}
# {'timestamp': 1665624695753926062, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.91, 'exit_price': 4.93, 'profit': 1.9999999999999574}
# {'timestamp': 1665624695753926062, 'action': 'OPEN', 'position': -100, 'price': 4.93}
# {'timestamp': 1665624699469585960, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.93, 'exit_price': 4.94, 'profit': -1.0000000000000675}
# {'timestamp': 1665624699469585960, 'action': 'OPEN', 'position': 100, 'price': 4.94}
# {'timestamp': 1665624700483232965, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.94, 'exit_price': 4.94, 'profit': 0.0}
# {'timestamp': 1665624700483232965, 'action': 'OPEN', 'position': -100, 'price': 4.94}
# {'timestamp': 1665624721514429597, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.94, 'exit_price': 4.93, 'profit': 1.0000000000000675}
# {'timestamp': 1665624721514429597, 'action': 'OPEN', 'position': 100, 'price': 4.93}
# {'timestamp': 1665625171831979710, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.93, 'exit_price': 4.9, 'profit': -2.999999999999936}
# {'timestamp': 1665625171831979710, 'action': 'OPEN', 'position': -100, 'price': 4.9}
# {'timestamp': 1665625172493490009, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.9, 'exit_price': 4.89, 'profit': 1.0000000000000675}
# {'timestamp': 1665625172493490009, 'action': 'OPEN', 'position': 100, 'price': 4.89}
# {'timestamp': 1665625874751672442, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.89, 'exit_price': 4.88, 'profit': -0.9999999999999787}
# {'timestamp': 1665625874751672442, 'action': 'OPEN', 'position': -100, 'price': 4.88}
# {'timestamp': 1665625874752893801, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': -0.0}
# {'timestamp': 1665625874752893801, 'action': 'OPEN', 'position': 100, 'price': 4.88}
# {'timestamp': 1665625874772492534, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': 0.0}
# {'timestamp': 1665625874772492534, 'action': 'OPEN', 'position': -100, 'price': 4.88}
# {'timestamp': 1665625876520959143, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.88, 'exit_price': 4.88, 'profit': -0.0}
# {'timestamp': 1665625876520959143, 'action': 'OPEN', 'position': 100, 'price': 4.88}
# {'timestamp': 1665626044530896648, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.88, 'exit_price': 4.89, 'profit': 0.9999999999999787}
# {'timestamp': 1665626044530896648, 'action': 'OPEN', 'position': -100, 'price': 4.89}
# {'timestamp': 1665626044641045748, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.89, 'exit_price': 4.89, 'profit': -0.0}
# {'timestamp': 1665626044641045748, 'action': 'OPEN', 'position': 100, 'price': 4.89}
# {'timestamp': 1665626047540948649, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.89, 'exit_price': 4.89, 'profit': 0.0}
# {'timestamp': 1665626047540948649, 'action': 'OPEN', 'position': -100, 'price': 4.89}
# {'timestamp': 1665626049826904276, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.89, 'exit_price': 4.89, 'profit': -0.0}
# {'timestamp': 1665626049826904276, 'action': 'OPEN', 'position': 100, 'price': 4.89}
# {'timestamp': 1665626050522152947, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.89, 'exit_price': 4.89, 'profit': 0.0}
# {'timestamp': 1665626050522152947, 'action': 'OPEN', 'position': -100, 'price': 4.89}
# {'timestamp': 1665626052525416128, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.89, 'exit_price': 4.89, 'profit': -0.0}
# {'timestamp': 1665626052525416128, 'action': 'OPEN', 'position': 100, 'price': 4.89}
# {'timestamp': 1665626055652481882, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.89, 'exit_price': 4.89, 'profit': 0.0}
# {'timestamp': 1665626055652481882, 'action': 'OPEN', 'position': -100, 'price': 4.89}
# {'timestamp': 1665626068528679038, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.89, 'exit_price': 4.88, 'profit': 0.9999999999999787}
# {'timestamp': 1665626068528679038, 'action': 'OPEN', 'position': 100, 'price': 4.88}
# {'timestamp': 1665626075794719656, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.88, 'exit_price': 4.89, 'profit': 0.9999999999999787}
# {'timestamp': 1665626075794719656, 'action': 'OPEN', 'position': -100, 'price': 4.89}
# {'timestamp': 1665626101106476714, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.89, 'exit_price': 4.88, 'profit': 0.9999999999999787}
# {'timestamp': 1665626101106476714, 'action': 'OPEN', 'position': 100, 'price': 4.88}
# {'timestamp': 1665626183740273690, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.88, 'exit_price': 4.89, 'profit': 0.9999999999999787}
# {'timestamp': 1665626183740273690, 'action': 'OPEN', 'position': -100, 'price': 4.89}
# {'timestamp': 1665626188542849531, 'action': 'CLOSE', 'position': -100, 'entry_price': 4.89, 'exit_price': 4.89, 'profit': -0.0}
# {'timestamp': 1665626188542849531, 'action': 'OPEN', 'position': 100, 'price': 4.89}
# {'timestamp': 1665644199110990586, 'action': 'CLOSE', 'position': 100, 'entry_price': 4.89, 'exit_price': 4.99, 'profit': 10.000000000000053}
# interactive(children=(Dropdown(description='Day:', options=(datetime.date(2022, 9, 30), datetime.date(2022, 10…
